# %%
import pandas as pd

#CHANGE THIS DICT
df = pd.read_csv('orders_export_20230907-111954.csv')

SKU_dict = {
    'PALERMDLXE6SEAT': 'PALERMO-DLXE-EXT-6-SEAT-SET',
    'SMALL-PLANT2SCT': 'SMALL-PLANTER-2SCTS',
    'SHLLW-PLANTX2': 'SHLLW-PLANTERS-X2',
    'MALAGA-LOUNGE': 'MALAGA-LOUNGE-SET',
    'DELANOCAPPUC': 'DELANO-CAPPUCCINO',
    'STOCKHOLMCHAISE': 'STOCKHOLM-CHAISE-LOUNGE',
    'STOCKHOLMLOUNGE': 'STOCKHOLM-LOUNGE-SET',
    'MARRAKESHSET': 'Marrakesh Setting',
    'SANTORINI-GREY': 'SANTORINI-GREY',
    'SION-HEATER': 'SION-HEATER',
    'VERONA-HEATER': 'VERONA-HEATER',
    'TURIN-HEATER': 'TURIN-HEATER',
    'MODENA-HEATER': 'MODENA-HEATER',
    'FLORINA-HEATER': 'FLORINA-HEATER',
    'BORDEAUX-HEATER': 'BORDEAUX-HEATER',
    'LYON-HEATER': 'LYON-HEATER',
    'ZURICH-HEATER': 'ZURICH-HEATER',
    'ZURICH-DELUXE': 'ZURICH-DELUXE',
    'ASPENDOORTABOAK': 'ASPEN-DOOR-TABLE-OAK-NDD',
    'ASPENDRAWTABOAK': 'ASPEN-TABLE-1D-OAK',
    'ASPENOAKSIDEB2D': 'ASPEN-TV-OAK-2D',
    'ASPENOAKSIDEB': 'ASPEN-OAK-SIDEBOARD-NDD',
    'ASPENSIDEB-2D': 'ASPEN-TV-WHITE-2D',
    'ASPENWHITESIDEB': 'ASPEN-WHITE-SIDEBOARD-NDD',
    'BLACKGAMERDESK': 'BLACK-GAMER-DESK-NDD',
    'BLAKE VANITY': 'BLAKE-VANITY-DESK-140',
    'BROOKLYNTV170': 'BROOKLYN-TV-UNIT-170-NDD',
    'CHESTRCNRDESKWH': 'CHESTER-CNR-DESK-WHITE-NDD',
    'CHESTRCNRDESKOK': 'CHESTER-CORNER-DESK-OAK-NDD',
    'CHESTRDESKOK149': 'CHESTER-DESK-OAK-149-NDD',
    'CHESTRDESKOAK77': 'CHESTER-DESK-OAK-77-NDD',
    'CHESTERDESKWH77': 'CHESTER-DESK-WHITE-77-NDD',
    'CHESTRKIDDESKWH': 'CHESTER-KIDS-DESK-WHITE-NDD',
    'DAKOTBLKSIDETAB': 'DAKOTA-BLACK-SIDE-TABLE',
    'DAKOOPNSIDEBBLK': 'DAKOTA-OPEN-SIDEBOARD-BLACK',
    'DAKOOPENSIDEBWH': 'DAKOTA-OPEN-SIDEBOARD-WHITE',
    'DAKOTAOPENTVBLK': 'DAKOTA-OPEN-TV-UNIT-BLACK',
    'DAKOTAOPENTVWH': 'DAKOTA-OPEN-TV-UNIT-WHITE',
    'DAKOTOPENUNTBLK': 'DAKOTA-OPEN-UNIT-BLACK',
    'DAKOTAOPENUNTWH': 'DAKOTA-OPEN-UNIT-WHITE',
    'DAKOTASIDEBBLK': 'DAKOTA-SIDEBOARD-BLACK',
    'DAKOTASIDEBWH': 'DAKOTA-SIDEBOARD-WHITE',
    'DAKOTATVUNITBLK': 'DAKOTA-TV-UNIT-BLACK',
    'DAKOTATVUNITWH': 'DAKOTA-TV-UNIT-WHITE',
    'DAKOTAWHSIDETAB': 'DAKOTA-WHITE-SIDE-TABLE',
    'EMERSON VANITY': 'EMERSON-VANITY-DESK-150',
    'LEIGHTON VANTY': 'LEIGHTON-VANITY-DESK-140',
    'MEMPHISSB-TV-2D': 'MEMPHIS-WHITE-SB-TV-2D',
    'MEMPHISSIDEB1D': 'MEMPHIS-WHITE-SIDEBOARD-90',
    'MEMPHISTV160': 'MEMPHIS-WHITE-TV-160',
    'OSLOWHITESIDEB': 'OSLO-WHITE-SIDEBOARD-NDD',
    'OSLOWHITETVUNIT': 'OSLO-WHITE-TV-UNIT-NDD',
    'PHANTOMBLKSIDEB': 'PHANTOM-BLACK-SIDEBOARD-NDD',
    'PHOENIXWHITDESK': 'PHOENIX-WHITE-DESK-NDD',
    'SAVANASIDEB90': 'SAVANNAH-SIDEBOARD-90-NDD',
    'SAVANATABLE': 'SAVANNAH-TABLE-NDD',
    'SAVANATVUNIT150': 'SAVANNAH-TV-UNIT-150-NDD',
    'VOLACNRDESK': 'VOLA-CORNER-DESK-NDD',
    'VOLASIDEWHITE1D': 'VOLA-SIDEBOARD-WHITE-1D-NDD',
    'VOLASIDEWHITE2D': 'VOLA-SIDEBOARD-WHITE-2D-NDD',
    'VOLATVUNITWHITE': 'VOLA-TV-UNIT-WHITE-NDD',
    'BALIPARASLGREEN': 'BALI-WOOD-PARASOL-GREEN',
    'BERGENTABLEBLK': 'BERGEN-TABLE-BLACK',
    'APOLLO-COMPACT': 'APOLLO-COMPACT',
    'APOLLO-DELUXE': 'APOLLO-DELUXE',
    'ZORA-COMPACT': 'ZORA-COMPACT',
    'ZORA-DELUXE': 'ZORA-DELUXE',
    'EBONY-STANDARD': 'EBONY-STANDARD',
    'EBONY-DELUXE': 'EBONY-DELUXE',
    'EBONY-COMPACT': 'EBONY-COMPACT',
    'ARGON-COMPACT': 'ARGON-COMPACT',
    'ARGON-DELUXE': 'ARGON-DELUXE',
    'NEPTUNE-DELUXE': 'NEPTUNE-DELUXE',
    'NEPTUNE-COMPACT': 'NEPTUNE-COMPACT',
    'ORION-COMPACT': 'ORION-COMPACT',
    'ORION-STANDARD': 'ORION-STANDARD',
    'ORION-DELUXE': 'ORION-DELUXE',
    'marbellaloungst': 'Marbella Five Seater Corner',
    'SANTORINIBLUE': 'SANTOINI-BLUE',
    'FRS50837': 'FRS50837',
    'BALIMTLPRSLGREN': 'BALI-METAL-PARASOL-GREY',
    'BALIMTLPRSLTPE': 'BALI-METAL-PARASOL-TAUPE',
    'BALIWOODPRSLTPE': 'BALI-WOOD-PARASOL-TAUPE',
    'HAVANAPRSLGREY': 'HAVANA-PARASOL-GREY',
    'HAVANASQPRSL3X4': 'HAVANA-SQUARE-PARASOL-3X4',
    '25KGPARASLBASE': '25KG-PARASOL-BASE',
    'FARO-LOUNGE-SET': 'FARO-LOUNGE-SET',
    'ROMA-LNGE-SET': 'ROMA-LOUNGE-SET',
    'VISTA-LNGE-SET': 'VISTA-LOUNGE-SET',
    'NAPOLI-CONV-SET': 'NAPOLI-CONV-SET-DD',
    'NAPOLI-LNGE-SET': 'NAPOLI-LOUNGE-SET-DD',
    'BJORN-BLACK': 'BJORN-BLACK-LOUNGER',
    'BJORN-WHITE': 'BJORN-WHITE-LOUNGER',
    'TORBEN-LOUNGER': 'TORBEN-LOUNGER',
    'PARDIS-CNPY-400': 'PARADISO-CANOPY-400',
    'PARDIS-CNPY-300': 'PARADISO-CANOPY-300',
    'ORLNDO-CNPY-400': 'ORLANDO-CANOPY-400',
    'ORLNDO-CNPY-300': 'ORLANDO-CANOPY-300',
    'BORGIA-LNGE-SET': 'BORGIA-LOUNGE-SET-DD',
    'PLRMO-LNGE-SET': 'PALERMO-LOUNGE-SET',
    'FILIPO-LNGE-SET': 'FILIPPO-LOUNGE-SET',
    'AMALFI-LNGE-SET': 'AMALFI-LOUNGE-SET-DD-',
    'AMALFI-CONV-SET': 'AMALFI-CONV-SET-DD-',
    'AMALFI-DIN-6S': 'AMALFI-DINING-6S-DD',
    'CAPRI-MULTI-SET': 'CAPRI-MULTI-LOUNGE-SET',
    'CATLANO-STL-SET': 'CATALANO-CONV-SET-DD',
    'WESLEY-BENCH-2S': 'WESLEY-BENCH-2S',
    'HAZEL-BENCH-2S': 'HAZEL-BENCH-2S',
    'HAZEL-BENCH-3S': 'HAZEL-BENCH-3S',
    'RALEIGH-TABLE': 'RALEIGH-TABLE',
    'LEON-TABLE': 'LEON-TABLE',
    'HAZEL-CHAIR': 'HAZEL-CHAIR',
    'THORPE-CHAIR': 'THORPE-CHAIR',
    'LINCLN-LNGER': 'LINCOLN-LOUNGER',
    'EDEN-LOUNGER': 'EDEN-LOUNGER',
    'ALLEN-CHAIR': 'ALLEN-CHAIR',
    'TARYN-CHAIR': 'TARYN-CHAIR',
    'OLIVE-EXT-TABLE': 'OLIVE-EXT-TABLE',
    'MORRIS-TABLE': 'MORRIS-TABLE',
    'PENN-TABLE': 'PENN-TABLE',
    'PENN-TEAK-SET': 'PENN-TEAK-SET',
    'MORRIS-TEAK-SET': 'MORRIS-TEAK-SET',
    'LEON-ALLEN-4S': 'LEON-ALLEN-4S',
    'FLORENCEBED': 'FLORENCE-SOFA-BED-NDD',
    'PIPER-GREY': 'PIPER-CHAIR-GREY',
    'PIPER-PINK': 'PIPER-CHAIR-PINK',
    'SEATTLE-BLACK': 'SEATTLE-SB-BLACK',
    'SEATTLE-OAK': 'SEATTLE-SB-OAK',
    'SEATTLE-WHITE': 'SEATTLE-SB-WHITE',
    'LORNA-BLUE': 'LORNA-BLUE',
    'DALLASOAKBLACK': 'DALLAS-OAK-SB-BLACK',
    'DALLASOAKGREY': 'DALLAS-OAK-SB-GREY',
    'DALLASOAKWHITE': 'DALLAS-OAK-SB-WHITE',
    'DENVEROAKBLACK': 'DENVER-OAK-SB-BLACK',
    'DENVEROAKGREY': 'DENVER-OAK-SB-GREY',
    'DENVEROAKWHITE': 'DENVER-OAK-SB-WHITE',
    'CAMERON-190': 'CAMERON-BED-190',
    'CAMERON-200': 'CAMERON-BED-200',
    'ADDISON-BLACK': 'ADDISON-BED-BLACK',
    'ADDISON-CHROME': 'ADDISON-BED-CHROME',
    'SPEEDY-RED': 'SPEEDY-CHAIR-RED',
    'SPEEDY-BLUE': 'SPEEDY-CHAIR-BLUE',
    'SPEEDY-WHITE': 'SPEEDY-CHAIR-WHITE',
    'TALISAEXT4SWHT': 'TALISA-WHITE-EXT-SET',
    'TALISAEXT4STEAL': 'TALISA-TEAL-EXT-SET',
    'TALISAWHITEX2': 'TALISA-WHITE-X2',
    'TALISAGREYX2': 'TALISA-GREY-X2',
    'TALISATEALX2': 'TALISA-TEAL-X2',
    'MARTHA-WHITE': 'MARTHA-WHITE-CHAIR'
}

# %%
new_df = pd.DataFrame()

new_df['Order ID'] = df['Order Number']
new_df['Shipping Name'] = df['Shipping Fullname']
new_df['Shipping Address Line One'] = df['Shipping Address 1']
new_df['Shipping Address Line Two'] = df['Shipping Address 2']
new_df['Shipping Address City'] = df['Shipping City']
new_df['Shipping Address County'] = ''  # Empty column
new_df['Shipping Address Postcode'] = df['Shipping Postcode']
new_df['Shipping Address Country'] = 'UK'
new_df['Shipping Address ISO'] = 'GB'
new_df['Invoice Name Company'] = 'Robert Dyas'
new_df['Invoice Name'] = df['Shipping Fullname']
new_df['Invoice Address Line One'] = df['Shipping Address 1']
new_df['Invoice Address Line Two'] = df['Shipping Address 2']
new_df['Invoice Address City'] = df['Shipping City']
new_df['Invoice Address County'] = ''  # Empty column
new_df['Invoice Address Postcode'] = df['Shipping Postcode']
new_df['Invoice Address Country'] = 'UK'
new_df['Invoice Address ISO'] = 'GB'
new_df['Email'] = df['Shipping Email']
new_df['Phone One'] = df['Shipping Phone']
new_df['Payment Currency'] = ''  # Blank column
new_df['Total Paid'] = ''  # Blank column
new_df['Tax Paid'] = ''  # Blank column
new_df['Shipping Paid'] = ''  # Blank column
new_df['Total Weight'] = ''  # Blank column
new_df['Customer Comments'] = ''  # Blank column
new_df['Payment Method'] = ''  # Blank column
new_df['Payment Ref'] = ''  # Blank column
new_df['Shipping Method Requested'] = ''  # Blank column
new_df['Product Name'] = ''  # Blank column
new_df['Product SKU'] = df['Supplier SKU'].map(SKU_dict)
new_df['Product Quantity'] = df['Qty Ordered']
new_df['Product Price'] = ''  # Blank column
new_df['Product Total Discount'] = ''  # Blank column
new_df['Product Options'] = ''  # Blank column
new_df['Product Notes'] = ''  # Blank column


new_df.to_csv('transformed_info.csv', index=False)
